# %% [markdown]
# # Processing Hanja

# %%
# !pip install konlpy
import pandas as pd
from konlpy.tag import Kkma
from konlpy.utils import pprint
kkma = Kkma()
pprint(kkma.sentences(u'네, 안녕하세요. 반갑습니다.'))
# Out:
# Requirement already satisfied: konlpy in c:\programdata\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: JPype1>=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (1.4.0)
# Requirement already satisfied: numpy>=1.6 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (1.20.3)
# Requirement already satisfied: lxml>=4.1.0 in c:\programdata\anaconda3\lib\site-packages (from konlpy) (4.6.3)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ikit-learn (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution - (c:\programdata\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\programdata\anaconda3\lib\site-packages)
# ['네, 안녕하세요.', '반갑습니다.']

# %%
df_hanjas = pd.read_csv("hanjas.csv")

# %%
df_hanjas.head(10)
# Out:
#   hanja한자  strokes총획수 sound장단음 meaningKr_1 meaningKr_2 sound長短音  JLPT  \
# 0       含           7    머금을 함         머금다          품다     ふく.む     2
# 1       血           6      피 혈           피        물들이다        ち     3
# 2       噴          15     뿜을 분          뿜다         꾸짖다      ふ.く     1
# 3       人           2     사람 인          사람          인간       ひと     5
# 4       先           6     먼저 선          먼저          이전       さき     5
# 5       汚           6    더러울 오         더럽다         나쁘다      きたな     2
# 6       其           8      그 기           그          만약       それ     5
# 7       口           3      입 구           입          어귀       くち     4
# 8       海          10     바다 해          바다        바닷 물       うみ     4
# 9       不           4     아닐 부         아니다        아니하다        ふ     4
#
#   meaningEsp_1  meaningEsp_2
# 0      guardar       encubar
# 1       sangre         teñir
# 2      exhalar     reprender
# 3      persona        humano
# 4      primero  tranferencia
# 5   ensuciarse          malo
# 6          eso            si
# 7         boca       entrada
# 8          mar   agua de mar
# 9           no       negarse

# %%
pprint(kkma.pos(u'오류보고는 실행환경, 에러메세지와함께 설명을 최대한상세히!^^'))
# Out:
# [('오류', 'NNG'),
#  ('보고', 'NNG'),
#  ('는', 'JX'),
#  ('실행', 'NNG'),
#  ('환경', 'NNG'),
#  (',', 'SP'),
#  ('에러', 'NNG'),
#  ('메세지', 'NNG'),
#  ('와', 'JKM'),
#  ('함께', 'MAG'),
#  ('설명', 'NNG'),
#  ('을', 'JKO'),
#  ('최대한', 'NNG'),
#  ('상세히', 'MAG'),
#  ('!', 'SF'),
#  ('^^', 'EMO')]

# %%
pprint(kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.'))
# Out:
# ['질문', '건의', '건의사항', '사항', '깃헙', '이슈', '트래커']

# %%
type(kkma.nouns(u'질문이나 건의사항은 깃헙 이슈 트래커에 남겨주세요.'))
# Out:
# list

# %%
kkma.pos(str(df_hanjas['meaningKr_1'][:]))
# Out:
# [('0', 'NR'),
#  ('머금', 'VV'),
#  ('다', 'ECS'),
#  ('1', 'NR'),
#  ('피', 'NNG'),
#  ('2', 'NR'),
#  ('뿜', 'VV'),
#  ('다', 'ECS'),
#  ('3', 'NR'),
#  ('사람', 'NNG'),
#  ('4', 'NR'),
#  ('먼저', 'MAG'),
#  ('5', 'NR'),
#  ('더럽', 'VA'),
#  ('다', 'ECS'),
#  ('6', 'NR'),
#  ('그', 'MDT'),
#  ('7', 'NR'),
#  ('입', 'NNG'),
#  ('8', 'NR'),
#  ('바다', 'NNG'),
#  ('9', 'NR'),
#  ('아니', 'VV'),
#  ('다', 'ECS'),
#  ('10', 'NR'),
#  ('사', 'VV'),
#  ('아', 'ECS'),
#  ('양하', 'NNG'),
#  ('이', 'VCP'),
#  ('다', 'EFN'),
#  ('11', 'NR'),
#  ('물', 'NNG'),
#  ('12', 'NR'),
#  ('능', 'NNG'),
#  ('하', 'XSV'),
#  ('다', 'ECS'),
#  ('13', 'NR'),
#  ('넓', 'VA'),
#  ('다', 'ECS'),
#  ('14', 'NR'),
#  ('크', 'VA'),
#  ('다', 'ECS'),
#  ('15', 'NR'),
#  ('알', 'VV'),
#  ('다', 'ECS'),
#  ('16', 'NR'),
#  ('발', 'NNB'),
#  ('17', 'NR'),
#  ('옳', 'VA'),
#  ('다', 'ECS'),
#  ('18', 'NR'),
#  ('노래', 'NNG'),
#  ('19', 'NR'),
#  ('힘쓰', 'VV'),
#  ('다', 'ECS'),
#  ('20', 'NR'),
#  ('탐내', 'VV'),
#  ('다', 'ECS'),
#  ('21', 'NR'),
#  ('법칙', 'NNG'),
#  ('22', 'NR'),
#  ('근심', 'NNG'),
#  ('23', 'NR'),
#  ('저', 'VV'),
#  ('어', 'ECS'),
#  ('24', 'NR'),
#  ('몸', 'NNG'),
#  ('25', 'NR'),
#  ('백', 'NR'),
#  ('26', 'NR'),
#  ('싸우', 'VV'),
#  ('다', 'ECS'),
#  ('27', 'NR'),
#  ('위태', 'NNG'),
#  ('하다', 'NNP'),
#  ('28', 'NR'),
#  ('몸', 'NNG'),
#  ('29', 'NR'),
#  ('몸', 'NNG'),
#  ('30', 'NR'),
#  ('터', 'NNG'),
#  ('력', 'XSN'),
#  ('31', 'NR'),
#  ('살갗', 'NNG'),
#  ('32', 'NR'),
#  ('받', 'VV'),
#  ('다', 'ECS'),
#  ('33', 'NR'),
#  ('가다', 'MAG'),
#  ('34', 'NR'),
#  ('아버지', 'NNG'),
#  ('35', 'NR'),
#  ('어머니', 'NNG'),
#  ('Name', 'OL'),
#  (':', 'SP'),
#  ('meaningKr', 'OL'),
#  ('_', 'SW'),
#  ('1', 'NR'),
#  (',', 'SP'),
#  ('dtype', 'OL'),
#  (':', 'SP'),
#  ('object', 'OL')]

# %%
pprint(kkma.pos(str(df_hanjas['meaningKr_1'][0])))
# Out:
# [('머금', 'VV'), ('다', 'EFN')]

# %%
df_hanjas['strokes총획수'].mean()
# Out:
# 9.027777777777779

# %%
df_hanjas['strokes총획수'].max()
# Out:
# 24

# %%
df_hanjas['strokes총획수'].min()
# Out:
# 2

# %%
df_hanjas['JLPT'].mean()
# Out:
# 3.3333333333333335

# %%
df_hanjas[['A', 'B']] = df_hanjas['sound장단음'].str.split(' ', 1, expand=True)

# %%
lst_indexes = ['부','모']
 
 
rows = df_hanjas[df_hanjas['B'].isin(lst_indexes)]
print(rows)
# Out:
#    hanja한자  strokes총획수 sound장단음 meaningKr_1 meaningKr_2 sound長短音  JLPT  \
# 9        不           4     아닐 부         아니다        아니하다        ふ     4
# 31       膚          15     살갗 부          살갗         겉껍질       はだ     2
# 35       母           5    어머니 모         어머니         NaN       はは     5
#
#    meaningEsp_1   meaningEsp_2    A  B
# 9            no        negarse   아닐  부
# 31        piel   piel exterior   살갗  부
# 35        madre            NaN  어머니  모

# %%
df_hanjas['장단음']=None
df_hanjas
# Out:
#    hanja한자  strokes총획수           sound장단음 meaningKr_1 meaningKr_2 sound長短音  \
# 0        含           7              머금을 함         머금다          품다     ふく.む
# 1        血           6                피 혈           피        물들이다        ち
# 2        噴          15               뿜을 분          뿜다         꾸짖다      ふ.く
# 3        人           2               사람 인          사람          인간       ひと
# 4        先           6               먼저 선          먼저          이전       さき
# 5        汚           6              더러울 오         더럽다         나쁘다      きたな
# 6        其           8                그 기           그          만약       それ
# 7        口           3                입 구           입          어귀       くち
# 8        海          10               바다 해          바다        바닷 물       うみ
# 9        不           4               아닐 부         아니다        아니하다        ふ
# 10       讓          24              사양할 양        사양하다        양보하다     ゆず.る
# 11       水           4                물 수           물          강물       みず
# 12       能          10               능할 능         능하다         견디다        の
# 13       廣          15               넓을 광          넓다          크다     ひろ.い
# 14       大           3                클 대          크다          높다       だい
# 15       知           8                알 지          알다         알리다        チ
# 16       足           7                발 족           발         족하다       あし
# 17       可           5               옳을 가          옳다        하락하다        カ
# 18       樂          15  노래 악, 즐길 락, 좋아할 요          노래         즐기다       らく
# 19       務          11               힘쓸 무         힘쓰다        권면하다      つとめ
# 20       貪          11               탐낼 탐         탐내다         바라다      むさぼ
# 21       則           9          법칙 칙, 곧 즉          법칙           곧       のり
# 22       憂          15               근심 우          근심          질병        う
# 23       彼           8                저 피           저           그       かれ
# 24       己           3                몸 기           몸          자기      おのれ
# 25       百           6         일백 백, 힘쓸 맥           백          온갖      ヒャク
# 26       戰          16               싸움 전         싸우다          경기      いくさ
# 27       危           6              위태할 위        위태하다          거의        キ
# 28       身           7       몸 신, 나라 이름 건           몸       나라 이름        み
# 29       體          24                 몸체           몸         NaN       テイ
# 30       髮          15               터력 발          터력         NaN       かみ
# 31       膚          15               살갗 부          살갗         겉껍질       はだ
# 32       受           8               받을 수          받다          얻다        う
# 33       之           4                갈 지          가다           의       これ
# 34       父           4    아버지 부,아비 부, 자 보         아버지          아비       ちち
# 35       母           5              어머니 모         어머니         NaN       はは
#
#     JLPT   meaningEsp_1    meaningEsp_2    A               B   장단음
# 0      2        guardar         encubar  머금을               함  None
# 1      3         sangre           teñir    피               혈  None
# 2      1        exhalar       reprender   뿜을               분  None
# 3      5        persona          humano   사람               인  None
# 4      5        primero    tranferencia   먼저               선  None
# 5      2     ensuciarse            malo  더러울               오  None
# 6      5            eso              si    그               기  None
# 7      4           boca         entrada    입               구  None
# 8      4            mar     agua de mar   바다               해  None
# 9      4             no         negarse   아닐               부  None
# 10     1       rechazar           ceder  사양할               양  None
# 11     5           agua             río    물               수  None
# 12     3      ser hábil        aguantar   능할               능  None
# 13     5      ser ampli      ser grande   넓을               광  None
# 14     5     ser grande        ser alto    클               대  None
# 15     4          saber       notificar    알               지  None
# 16     4         pierna  ser suficiente    발               족  None
# 17     5   ser correcto           bajar   옳을               가  None
# 18     2        canción       disfrutar   노래  악, 즐길 락, 좋아할 요  None
# 19     3     esforzarse      recomendar   힘쓸               무  None
# 20     3       codiciar          desear   탐낼               탐  None
# 21     2            ley      en seguida   법칙          칙, 곧 즉  None
# 22     1   preocupación      enfermedad   근심               우  None
# 23     3             yo              él    저               피  None
# 24     1         cuerpo        si mismo    몸               기  None
# 25     5           cien           todos   일백         백, 힘쓸 맥  None
# 26     3         pelear            game   싸움               전  None
# 27     3  ser peligroso            casi  위태할               위  None
# 28     3         cuerpo  nombre de país    몸      신, 나라 이름 건  None
# 29     4         cuerpo             NaN   몸체            None  None
# 30     4        cabello             NaN   터력               발  None
# 31     2          piel    piel exterior   살갗               부  None
# 32     3        recibir         obtener   받을               수  None
# 33     1             ir              de    갈               지  None
# 34     5          padre            papá  아버지     부,아비 부, 자 보  None
# 35     5          madre             NaN  어머니               모  None

# %%
index_full_sound = data.columns.get_loc('sound장단음')
index_sound = data.columns.get_loc('장단음')
