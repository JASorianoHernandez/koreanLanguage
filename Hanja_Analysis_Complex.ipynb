# %% [markdown]
# # Processing Hanja

# %%
import pandas as pd

# %%
df_hanjas = pd.read_csv("hanjas.csv")

# %%
df_hanjas.head(10)
# Out:
#   hanja한자  strokes 획 sound장단음 meaningKr_1 meaningKr_2 sound長短音  JLPT  \
# 0       含          7    머금을 함         머금다          품다     ふく.む     2
# 1       血          6      피 혈           피        물들이다        ち     3
# 2       噴         15     뿜을 분          뿜다         꾸짖다      ふ.く     1
# 3       人          2     사람 인          사람          인간       ひと     5
# 4       先          6     먼저 선          먼저          이전       さき     5
# 5       汚          6    더러울 오         더럽다         나쁘다      きたな     2
# 6       其          8      그 기           그          만약       それ     5
# 7       口          3      입 구           입          어귀       くち     4
#
#   meaningEsp_1  meaningEsp_2
# 0      guardar       encubar
# 1       sangre         teñir
# 2      exhalar     reprender
# 3      persona        humano
# 4      primero  tranferencia
# 5   ensuciarse          malo
# 6          eso            si
# 7         boca       entrada
